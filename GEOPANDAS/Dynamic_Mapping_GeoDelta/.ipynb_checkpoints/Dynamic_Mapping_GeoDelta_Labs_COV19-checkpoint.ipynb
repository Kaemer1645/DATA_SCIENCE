# %%
Code basen on GeoDelta Tutorial via YouTube

# %%
import pandas as pd
import geopandas as gpd

# %%
data_confirmed = pd.read_html('https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
for df_confirmed in data_confirmed:
    pass
df_confirmed = df_confirmed
df_confirmed.head()
# Out:
#    Unnamed: 0 Province/State Country/Region       Lat       Long  1/22/20  \
# 0         NaN            NaN    Afghanistan  33.93911  67.709953        0
# 1         NaN            NaN        Albania  41.15330  20.168300        0
# 2         NaN            NaN        Algeria  28.03390   1.659600        0
# 3         NaN            NaN        Andorra  42.50630   1.521800        0
# 4         NaN            NaN         Angola -11.20270  17.873900        0
#
#    1/23/20  1/24/20  1/25/20  1/26/20  ...  9/13/20  9/14/20  9/15/20  \
# 0        0        0        0        0  ...    38716    38772    38815
# 1        0        0        0        0  ...    11353    11520    11672
# 2        0        0        0        0  ...    48254    48496    48734
# 3        0        0        0        0  ...     1344     1438     1438
# 4        0        0        0        0  ...     3388     3439     3569
#
#    9/16/20  9/17/20  9/18/20  9/19/20  9/20/20  9/21/20  9/22/20
# 0    38855    38872    38883    38919    39044    39074    39096
# 1    11816    11948    12073    12226    12385    12535    12666
# 2    48966    49194    49413    49623    49826    50023    50214
# 3     1483     1483     1564     1564     1564     1681     1681
# 4     3675     3789     3848     3901     3991     4117     4236
#
# [5 rows x 250 columns]

# %%
df_confirmed = df_confirmed.groupby('Country/Region').sum()

# %%
df_confirmed = df_confirmed.drop(columns = ['Lat','Long','Unnamed: 0'])

# %%
df_confirmed
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
#                     1/28/20  1/29/20  1/30/20  1/31/20  ...  9/13/20  9/14/20  \
# Country/Region                                          ...
# Afghanistan               0        0        0        0  ...    38716    38772
# Albania                   0        0        0        0  ...    11353    11520
# Algeria                   0        0        0        0  ...    48254    48496
# Andorra                   0        0        0        0  ...     1344     1438
# Angola                    0        0        0        0  ...     3388     3439
# ...                     ...      ...      ...      ...  ...      ...      ...
# West Bank and Gaza        0        0        0        0  ...    30574    31362
# Western Sahara            0        0        0        0  ...       10       10
# Yemen                     0        0        0        0  ...     2011     2013
# Zambia                    0        0        0        0  ...    13539    13720
# Zimbabwe                  0        0        0        0  ...     7526     7531
#
#                     9/15/20  9/16/20  9/17/20  9/18/20  9/19/20  9/20/20  \
# Country/Region
# Afghanistan           38815    38855    38872    38883    38919    39044
# Albania               11672    11816    11948    12073    12226    12385
# Algeria               48734    48966    49194    49413    49623    49826
# Andorra                1438     1483     1483     1564     1564     1564
# Angola                 3569     3675     3789     3848     3901     3991
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza    32250    33006    33843    34401    35003    35686
# Western Sahara           10       10       10       10       10       10
# Yemen                  2016     2019     2022     2024     2026     2026
# Zambia                13819    13887    13928    14022    14070    14131
# Zimbabwe               7576     7598     7633     7647     7672     7683
#
#                     9/21/20  9/22/20
# Country/Region
# Afghanistan           39074    39096
# Albania               12535    12666
# Algeria               50023    50214
# Andorra                1681     1681
# Angola                 4117     4236
# ...                     ...      ...
# West Bank and Gaza    36151    36580
# Western Sahara           10       10
# Yemen                  2028     2028
# Zambia                14175    14389
# Zimbabwe               7683     7711
#
# [188 rows x 245 columns]

# %%
df_confirmed_transpose = df_confirmed.T

# %%
df_confirmed_transpose.plot(y = ['Poland','China','Germany'], use_index = True, figsize=(10,10))
